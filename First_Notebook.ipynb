# %% [markdown]
# <a href="https://colab.research.google.com/github/Evelyn-3877/ai-data-science/blob/main/First_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name?")
# Out:
# What is your name?Evelyn

# %% [markdown]
# Ask the students to enter their name

# %%
scores = [85,90,95]
average = sum(scores) / len(scores)
print("Hello,", name)
print("Your average score is:",
average)
# Out:
# Hello, Evelyn
# Your average score is: 90.0
